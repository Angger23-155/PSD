# %% [markdown]
# # **VOICE DETECTION**

# %%
pip install librosa soundfile tqdm numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00:00:0100:01
# ...
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [librosa]9/10 [librosa]d]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
pip install ffmpeg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'ffmpeg' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'ffmpeg'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6127 sha256=8a5e241e9e7f7ec19bc68989dbdae800c1cc49fb475e33dab24418ea1b3aa98b
#   Stored in directory: /home/codespace/.cache/pip/wheels/26/21/0c/c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
# Successfully built ffmpeg
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import librosa
import soundfile as sf
import numpy as np
from tqdm import tqdm

folders = ['data/buka', 'data/tutup']

def augment_audio(y, sr):
    augmented_audios = []

    # 1️⃣ Pitch shift (ubah nada)
    n_steps = np.random.uniform(-2, 2)
    y_pitch = librosa.effects.pitch_shift(y=y, sr=sr, n_steps=n_steps)
    augmented_audios.append(y_pitch)

    # 2️⃣ Time stretch (ubah kecepatan)
    rate = np.random.uniform(0.9, 1.1)
    y_stretch = librosa.effects.time_stretch(y, rate=rate)
    augmented_audios.append(y_stretch)

    # 3️⃣ Tambah noise
    noise = np.random.randn(len(y)) * 0.005
    y_noise = y + noise
    augmented_audios.append(y_noise)

    # 4️⃣ Kombinasi pitch + noise
    y_combo = librosa.effects.pitch_shift(y=y, sr=sr, n_steps=np.random.uniform(-1.5, 1.5))
    y_combo = y_combo + np.random.randn(len(y_combo)) * 0.004
    augmented_audios.append(y_combo)

    # 5️⃣ Time stretch + pitch
    y_mix = librosa.effects.time_stretch(y, rate=np.random.uniform(0.95, 1.05))
    y_mix = librosa.effects.pitch_shift(y=y_mix, sr=sr, n_steps=np.random.uniform(-1, 1))
    augmented_audios.append(y_mix)

    return augmented_audios


for folder in folders:
    files = [f for f in os.listdir(folder) if f.endswith('.wav')]
    print(f"🔊 Memproses folder: {folder} (total {len(files)} file asli)")

    for f in tqdm(files):
        file_path = os.path.join(folder, f)
        y, sr = librosa.load(file_path, sr=None)

        aug_audios = augment_audio(y, sr)

        base_name = os.path.splitext(f)[0]
        for i, aug in enumerate(aug_audios):
            out_name = f"{base_name}_aug{i+1}.wav"
            out_path = os.path.join(folder, out_name)
            sf.write(out_path, aug, sr)

print("✅ Augmentasi selesai! Sekarang setiap folder punya ±100 file suara.")
# Out:
# 🔊 Memproses folder: data/buka (total 20 file asli)
# 100%|██████████| 20/20 [00:05<00:00,  3.49it/s]
# 🔊 Memproses folder: data/tutup (total 20 file asli)
# 100%|██████████| 20/20 [00:02<00:00,  7.18it/s]
# ✅ Augmentasi selesai! Sekarang setiap folder punya ±100 file suara.
